# %% [markdown]
# <a href="https://colab.research.google.com/github/prajwalnigam321/Data-Science-and-Machine-Learning/blob/main/Project_Ad_Ease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ad Ease
# is an ads and marketing based company helping businesses elicit maximum clicks at minimum cost. AdEase is an ad infrastructure to help businesses promote themselves easily, effectively, and economically. The interplay of 3 AI modules - Design, Dispense, and Decipher, come together to make it this an end-to-end 3 step process digital advertising solution for all.

# %% [markdown]
# ## Problem Statement:
# * To understand the per page view report for different wikipedia pages for 550 days. Dataset: https://www.kaggle.com/datasets/saimaharana/adease/data
# * To forecast the number of views to predict and optimize the ad placement for clients
# * To provide clients (different regions) with data on how their ads will perform on pages in different languages

# %%
# Importing required packages for analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
# Initial pandas & matplotlib setup

pd.options.display.max_rows = 200
pd.options.display.max_columns = 600
pd.options.display.max_colwidth = 200

np.set_printoptions(precision=2,suppress=True)

#to suppress scientific notation
pd.options.display.float_format = '{:.2f}'.format

plt.rcParams["figure.figsize"] = (20,6)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# To increase jupyter notebook cell width
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Importing the given dataset to pandas dataframe
data = pd.read_csv("./Data/train_1.csv")
df = data.copy()
df.head(5)
# Out:
#                                                   Page  2015-07-01  \
# 0              2NE1_zh.wikipedia.org_all-access_spider       18.00
# 1               2PM_zh.wikipedia.org_all-access_spider       11.00
# 2                3C_zh.wikipedia.org_all-access_spider        1.00
# 3           4minute_zh.wikipedia.org_all-access_spider       35.00
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_spider         NaN
#
#    2015-07-02  2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  \
# 0       11.00        5.00       13.00       14.00        9.00        9.00
# 1       14.00       15.00       18.00       11.00       13.00       22.00
# 2        0.00        1.00        1.00        0.00        4.00        0.00
# 3       13.00       10.00       94.00        4.00       26.00       14.00
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-07-08  2015-07-09  2015-07-10  2015-07-11  2015-07-12  2015-07-13  \
# 0       22.00       26.00       24.00       19.00       10.00       14.00
# 1       11.00       10.00        4.00       41.00       65.00       57.00
# 2        3.00        4.00        4.00        1.00        1.00        1.00
# 3        9.00       11.00       16.00       16.00       11.00       23.00
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-07-14  2015-07-15  2015-07-16  2015-07-17  2015-07-18  2015-07-19  \
# 0       15.00        8.00       16.00        8.00        8.00       16.00
# 1       38.00       20.00       62.00       44.00       15.00       10.00
# 2        6.00        8.00        6.00        4.00        5.00        1.00
# 3      145.00       14.00       17.00       85.00        4.00       30.00
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-07-20  2015-07-21  2015-07-22  2015-07-23  2015-07-24  2015-07-25  \
# 0        7.00       11.00       10.00       20.00       18.00       15.00
# 1       47.00       24.00       17.00       22.00        9.00       39.00
# 2        2.00        3.00        8.00        8.00        6.00        6.00
# 3       22.00        9.00       10.00       11.00        7.00        7.00
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-07-26  2015-07-27  2015-07-28  2015-07-29  2015-07-30  2015-07-31  \
# 0       14.00       49.00       10.00       16.00       18.00        8.00
# 1       13.00       11.00       12.00       21.00       19.00        9.00
# 2        2.00        2.00        3.00        2.00        4.00        3.00
# 3       11.00        9.00       11.00       44.00        8.00       14.00
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-08-01  2015-08-02  2015-08-03  2015-08-04  2015-08-05  2015-08-06  \
# 0        5.00        9.00        7.00       13.00        9.00        7.00
# 1       15.00       33.00        8.00        8.00        7.00       13.00
# 2        3.00        5.00        3.00        5.00        4.00        2.00
# 3       19.00       10.00       17.00       17.00       10.00        7.00
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    2015-08
# 3       13.00       23.00       40.00       16.00       17.00       41.00
# 4        7.00        9.00        8.00        5.00       11.00        8.00
#
#    2016-12-11  2016-12-12  2016-12-13  2016-12-14  2016-12-15  2016-12-16  \
# 0       60.00       22.00       15.00       17.00       19.00       18.00
# 1       17.00       17.00       13.00        9.00       18.00       22.00
# 2        9.00        8.00        3.00      210.00        5.00        4.00
# 3       17.00        8.00        9.00       18.00       12.00       12.00
# 4        4.00       15.00        5.00        8.00        8.00        6.00
#
#    2016-12-17  2016-12-18  2016-12-19  2016-12-20  2016-12-21  2016-12-22  \
# 0       21.00       21.00       47.00       65.00       17.00       32.00
# 1       17.00       15.00       22.00       23.00       19.00       17.00
# 2        6.00        2.00        2.00        4.00        3.00        3.00
# 3       18.00       13.00       18.00       23.00       10.00       32.00
# 4        7.00       15.00        4.00       11.00        7.00       48.00
#
#    2016-12-23  2016-12-24  2016-12-25  2016-12-26  2016-12-27  2016-12-28  \
# 0       63.00       15.00       26.00       14.00       20.00       22.00
# 1       42.00       28.00       15.00        9.00       30.00       52.00
# 2        1.00        1.00        7.00        4.00        4.00        6.00
# 3       10.00       26.00       27.00       16.00       11.00       17.00
# 4        9.00       25.00       13.00        3.00       11.00       27.00
#
#    2016-12-29  2016-12-30  2016-12-31
# 0       19.00       18.00       20.00
# 1       45.00       26.00       20.00
# 2        3.00        4.00       17.00
# 3       19.00       10.00       11.00
# 4       13.00       36.00       10.00

# %%
# Load the exogenous varaible info
exog = pd.read_csv("./Data/Exog_Campaign_eng.csv")
exog.shape
# Out:
# (550, 1)

# %%
# Lets look at the distribution
exog.value_counts()
# Out:
# Exog
# 0       496
# 1        54
# Name: count, dtype: int64

# %%
# To get the shape of the dataset
print(f"Number of records : {df.shape[0]}")
print(f"Total Features:  {df.shape[1]}")
# Out:
# Number of records : 145063
# Total Features:  551

# %%
df.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145063 entries, 0 to 145062
# Columns: 551 entries, Page to 2016-12-31
# dtypes: float64(550), object(1)
# memory usage: 609.8+ MB

# %%
# Let's find max percentage of missing values
np.round((df.isna().sum()/df.shape[0]).max()*100)
# Out:
# 14.0

# %%
# Lets plot the distribution of null values
plt.figure(figsize=(5,5))
(df.isna().sum()*100/df.shape[0]).plot(kind="hist",bins=20)
plt.show();

# %% [markdown]
# ### Insights:
# 1. There is one feature of type object & rest of 550 features are float type
# 2. Maximum percentage of missing values in a feature is ~14 %
# 3. Above shows the histogram of % null values in different columns

# %%
# Null values for different dates
plt.figure(figsize=(5,5))
df.iloc[:,1:].isna().sum(axis=0).plot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Insights:
# 1. Above plot implies that all pages do not have views data starting from 07/01/2015
# 2. As we approach Year 2016, we have less and less null data
# 3. It could mean different things. Data isn't captured, Page didn't exist those days, or No one visited the page those days
# 4. For this analysis, I will perform interpolation using forward method so that initial null values remain as null

# %%
# Get the date range of columns
start_date, end_date = df.columns[1:].min(), df.columns[1:].max()
print(f"Columns date range: {start_date} till {end_date}")
# Out:
# Columns date range: 2015-07-01 till 2016-12-31

# %% [markdown]
# ### Insights:
# 1. There are 550 days of per day views data for roughly 145,000 pages from different languages
# 2. We have per day view data starting from 2015-07-01 till 2016-12-26

# %%
## Drop duplicates if available
df = df.drop_duplicates()
df.shape
# Out:
# (145063, 551)

# %%
# Drop all the rows where views for all dates are missing
df = df[~((df.isna().sum(axis=1) == 550))].copy()
df.shape
# Out:
# (144411, 551)

# %% [markdown]
# ### Insights:
# 1. There are no duplicates in the dataset
# 2. 0.45% (652) pages have all values as Null. Therefore dropped those pages

# %% [markdown]
# ### Data Checks:

# %%
# To check to see if we have all dates in columns - generate the date range
# Compare it with the columns of the dataset

_range = pd.date_range(start=start_date,end=end_date,freq="D")
print(f"Date mismataches: {(df.columns[1:] != _range).sum()}")
# Out:
# Date mismataches: 0

# %% [markdown]
# ### Insights:
# 1. Regardless of the null values, we have a column for each date. This check is to prevent issues during modelling

# %%
# Check the format of Page feature
df.iloc[[77573,42243,1],0]
# Out:
# 77912    Category:Threesome_commons.wikimedia.org_mobile-web_all-agents
# 42409               Help:Images/fr_www.mediawiki.org_desktop_all-agents
# 1                                2PM_zh.wikipedia.org_all-access_spider
# Name: Page, dtype: object

# %% [markdown]
# ### Insights:
# 1. There are also pages that do not comply with format: SPECIFIC NAME _ LANGUAGE.wikipedia.org _ ACCESS TYPE _ ACCESS ORIGIN
# 2. As shown above, there are also pages from commons.wikimedia & mediawiki. Simple google search shows the commons.wikimedia & Mediawiki is a media file repository. - These pages seem to have multilingual capabilities. For this analysis, we can assume language is unknown

# %%
def extract_features(df):

    import re
    pattern = r"([a-z]{2}).wikipedia.org"

    tempDf = df.Page.str.rsplit("_",n=2,expand=True)

    df.loc[:,"AccessType"] = tempDf[1]
    df.loc[:,"AccessOrigin"] = tempDf[2]
    df.loc[:,"Language"] = df.Page.str.extract(pattern)
    df.loc[:,"Org"] = tempDf[0].str.rsplit("_",n=1,expand=True).loc[:,1]
    df.loc[:,"PageName"] = tempDf[0].str.rsplit("_",n=1,expand=True).loc[:,0]

    return df

# %%
# Using the above function, lets extract the features like Language, AccessType, AccessOrigin, PageName from Page
data = extract_features(df)

# To change datatypes back to float for date features
for col in data.columns[1:-5]:
    data[col] = data[col].astype("float")

# %%
# Replace null values in Language with "unknown"
data["Language"].fillna("Unknown",inplace=True)

# %%
# Create a map to replace the language code with corresponding language

language_map = {
    "en": "English",
    "ja": "Japanese",
    "de": "German",
    "fr": "French",
    "zh": "Chinese",
    "ru": "Russian",
    "es": "Spanish"
}

data["Language"] = data["Language"].replace(to_replace=language_map)

# %%
data["Language"].unique()
# Out:
# array(['Chinese', 'French', 'English', 'Unknown', 'Russian', 'German',
#        'Japanese', 'Spanish'], dtype=object)

# %% [markdown]
# ### Insights:
# 1. There are pages from 7 differnt languages as shown above. Unknown is filled in for pages from commons.wikimedia & mediawiki pages

# %% [markdown]
# ### Univariate Analysis:

# %%
# Pages proportion by language
data["Language"].value_counts()*100/data.shape[0]
# Out:
# Language
# English    16.63
# Japanese   14.08
# German     12.77
# French     12.30
# Unknown    12.28
# Chinese    11.84
# Russian    10.38
# Spanish     9.72
# Name: count, dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.countplot(data=data,x="Language",order=data["Language"].value_counts().index)
plt.xticks(rotation=90);

# %% [markdown]
# ### Insights:
# 1. ~ 17% of the pages are in English. Closely followed by Japanese ~14%
# 2. Rest of the languages have almost equal proportion of ~12%

# %%
# pie plot to analyze the distribution
plt.figure(figsize=(5,5))

labels = data["AccessOrigin"].value_counts().index
counts = data["AccessOrigin"].value_counts().values

plt.pie(counts,labels=labels,autopct='%1.0f%%');

# %% [markdown]
# ### Insights:
# 1. AccessOrigin is spider for ~24% of the pages and all-agents for ~76%

# %%
# count plot
plt.figure(figsize=(5,5))
sns.countplot(y=data["AccessType"]);

# %% [markdown]
# ### Insights:
# 1. AccessType is all-acess for about 50% of the pages. Then for desktop & mobile-web is ~25% each

# %% [markdown]
# ### Bivariate Analysis:

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x="Language",hue="AccessType");

# %% [markdown]
# ### Insights:
# 1. English has more pages with AccessType of all-access, different from the rest

# %% [markdown]
# ### Data Aggregation & Preparation for Timeseries Modelling:

# %%
# Interpolate the data with linear method
interpolated_data = data.copy(deep=True)
interpolated_data.iloc[:,1:-5] = data.iloc[:,1:-5].interpolate(axis=1,limit_direction="forward",method="linear")

# %%
# Aggregate the pages by language & computes means
agg_data_means = interpolated_data.groupby(by="Language")[interpolated_data.columns[1:-5]].mean().T
agg_data_means.drop(columns=["Unknown"],inplace=True)
agg_data_means.index = pd.to_datetime(agg_data_means.index)

# %%
# Aggregate the pages by language & computes medians
agg_data_medians = interpolated_data.groupby(by="Language")[interpolated_data.columns[1:-5]].median().T
agg_data_medians.drop(columns=["Unknown"],inplace=True)
agg_data_medians.index = pd.to_datetime(agg_data_medians.index)

# %%
# Aggregate the pages by language & computes sum
agg_data_sum = interpolated_data.groupby(by="Language")[interpolated_data.columns[1:-5]].sum().T
agg_data_sum.drop(columns=["Unknown"],inplace=True)
agg_data_sum.index = pd.to_datetime(agg_data_sum.index)

# %%
sns.set_theme()
agg_data_means.plot()
plt.xlabel("Date")
plt.ylabel("Daily Average Page Views");

# %% [markdown]
# ### Insights:
# 1. During the months of August 2016, there is a spike in daily average views of both English & Russian pages
# 2. Also, a spike is observed in Nov,2016. This time for pages in Spanish, Russian, and German as well
# 3. English average views seem to have trend & seasonality where as other languages have seasonality mostly.

# %%
sns.set_theme()
agg_data_medians.plot()
plt.xlabel("Date")
plt.ylabel("Daily Median Page Views");

# %% [markdown]
# ### Insights:
# 1. In daily median views, Spanish language pages seem to be higher than other language pages
# 2. Spanish, Russian, and English median daily views had a drop.
# 3. In later months of 2016, english pages median daily views is on part with that of Spanish

# %%
sns.set_theme()
agg_data_sum.plot()
plt.xlabel("Date")
plt.ylabel("Daily Total Page Views");

# %% [markdown]
# ### Insights:
# 1. Given that English has high number of pages, it is no surprise that total daily views of English pages is high too
# 2. Daily total views of spanish seem to have some seasonality

# %%
# Null Hypothesis: Data is Not stationary
# Alternate Hypothesis: Data is stationary

import statsmodels.api as sm
def adFullerTest(data,alpha=0.05):

    """
    Given data series, outputs the result of adfuller test

    """
    testStatistic, p_value, *rest = sm.tsa.stattools.adfuller(data)

    if p_value < alpha:
        print(f"Signal is stationary:- p_value= {np.round(p_value,4)}")

    else:
        print(f"Signal is not stationary:- p_value= {np.round(p_value,4)}")

# %%
for language in agg_data_means.columns:
    print(language)
    adFullerTest(agg_data_means[language])
    print()
# Out:
# Chinese
# Signal is not stationary:- p_value= 0.2328
#
# English
# Signal is not stationary:- p_value= 0.1071
#
# French
# Signal is stationary:- p_value= 0.0256
#
# German
# Signal is not stationary:- p_value= 0.115
#
# Japanese
# Signal is stationary:- p_value= 0.046
#
# Russian
# Signal is stationary:- p_value= 0.0015
#
# Spanish
# Signal is stationary:- p_value= 0.0331

# %% [markdown]
# ### Insights:
# 1. Spanish, Russian, Japenese, French language series are stationary
# 2. English, German, Chinese are not stationary

# %% [markdown]
# ### Further analysis on aggregated English data:

# %%
English = agg_data_means["English"].copy()

# %%
# Lets plot the histogram of English
plt.figure(figsize=(5,5))
English.hist(bins=30);

# %%
plt.figure(figsize=(5,5))
English_clipped = English.clip(lower=English.quantile(0.01),upper=English.quantile(0.99))
English_clipped.hist(bins=30);

# %% [markdown]
# `

# %% [markdown]
# ### Insights:
# 1. Clipped the series using quantile technique with lower & upper quantiles as 0.01,0.99.
# 2. Looking at the plots, clipping seems optional

# %%
# Lets decompose the English signal further to understand trend, seasonality, residuals
decomp_english = sm.tsa.seasonal_decompose(English_clipped)
decomp_english.plot();

# %%
plt.figure(figsize=(10,5))
decomp_english.seasonal.head(30).plot();

# %%
plt.figure(figsize=(5,5))
decomp_english.resid.plot(kind="kde");

# %% [markdown]
# ### Insights:
#
# 1. Non stationary signals can be written as summation or multiplication of trend, seasonality, and residuals. As per the plots above, there is clearly seasonality in the data - Pattern repeats every 7 days. There is no clear Trend - increases, decreases, constant
# 2. Residual is normally distributed- No need to break down residual further

# %%
# Lets difference the data once to detrend
English.diff().plot()
English_clipped.diff().plot()
plt.legend();

# %%
# Check to see if the signal is stationary
adFullerTest(English_clipped.diff().dropna())
# Out:
# Signal is stationary:- p_value= 0.0

# %%
# Save the clipped data to different variable
Stationary_English_Clipped = English_clipped.diff().dropna()

# %%
# Lets plot auto correlation & partial auto correlation plots

sm.tsa.graphics.plot_acf(Stationary_English_Clipped);
sm.tsa.graphics.plot_pacf(Stationary_English_Clipped);

# %% [markdown]
# ### Insights:
# 1. In neither acf or pacf plot,s there is an exponential decaying trend. So, simple auto regression, or moving average wouldn't give better results
# 2. ARIMA, SARIMA, SARIMAX models would definitely do better than base models
# 3. You can observe, seasonality of 7 days in the above plots

# %%
import warnings
warnings.filterwarnings(action="ignore")

# %%
from sklearn.metrics import (
    mean_squared_error as mse,
    mean_absolute_error as mae,
    mean_absolute_percentage_error as mape
)

# Create a function to calculate all metrics
def performance(actual, predicted):
    print('MAE :', round(mae(actual, predicted), 3))
    print('RMSE :', round(mse(actual, predicted)**0.5, 3))
    print('MAPE:', round(mape(actual, predicted), 3))

# %% [markdown]
# ### Experimenting with differrent Modelling Techniques:

# %% [markdown]
# ### Exponential Smoothing

# %%
X_train = English_clipped[English_clipped.index <= English_clipped.index[-35]]
X_test = English_clipped[English_clipped.index > English_clipped.index[-35]]

# %%
ExpModel = sm.tsa.ExponentialSmoothing(X_train,seasonal="add",trend="add")
ExpModel = ExpModel.fit()

# %%
PredEnglish = ExpModel.forecast(35)
PredEnglish.plot(style='-o')
English_clipped.tail(100).plot()
plt.legend();

# %%
performance(English_clipped[-35:],PredEnglish)
# Out:
# MAE : 370.341
# RMSE : 479.683
# MAPE: 0.073

# %% [markdown]
# ### Insights:
# 1. Exponential model is able to predict the data with an MAPE of ~7%.
# 2. Lets check futher to see if other models do any better

# %% [markdown]
# ### ARIMA

# %%
def ARIMA(df,idx,order=(0,0,0),seasonal_order=(0,0,0,0)):

    import statsmodels.api as sm

    X_train, X_test = df.iloc[:-idx],df.iloc[-idx:]

    model = sm.tsa.ARIMA(endog=X_train,order=order,seasonal_order=seasonal_order)
    result = model.fit()

    predTest  = result.forecast(len(X_test))

    predTest.plot(style="-*",label="Prediction")
    df.tail(100).plot(label="Original")
    plt.ylabel("Views")
    plt.xlabel("Date")
    plt.legend();

    performance(X_test,predTest)
    print()

# %%
ARIMA(English_clipped,idx = 35,order=(1,1,1))
# Out:
# MAE : 342.994
# RMSE : 443.572
# MAPE: 0.068

# %% [markdown]
# ### Insights:
# 1. ARIMA with p,d,q as 1,1,1 is ableto predict the recent 35 days of data with ~6.8% MAPE

# %% [markdown]
# ### SARIMAX

# %% [markdown]
# 1. Below function can be used with and without exogeneous variable
# 2. Based on the order, seasonal_order, it can work as AR, MA, ARIMA, SARIMA, SARIMAX
# 3. Seasonal AutoRegressive Integrated Moving Average with Exogenous Regressors that use Moving average of errors, Auto regression on historical signal values, considers seasonality and external data to predict the future values

# %%
def SARIMAX(df,idx,order=(0,0,0),seasonal_order=(0,0,0,0),exog= None, batch=False):

    import statsmodels.api as sm

    X_train, X_test = df.iloc[:-idx],df.iloc[-idx:]

    if exog.shape[0]:
        exog_train = exog[:-idx]
        exog_test = exog[-idx:]

    model = sm.tsa.SARIMAX(endog=X_train,
                           exog=exog_train,
                           order=order,
                           seasonal_order=seasonal_order,
                          )
    result = model.fit(disp=False)
    predTest  = result.forecast(len(X_test),dynamic=False,exog=exog_test)

    if not batch:

        predTest.plot(style="-*",label="Prediction")
        df.tail(100).plot(label="Original")
        plt.ylabel("Views")
        plt.xlabel("Date")
        plt.legend();

        performance(X_test,predTest)

    return result.aic

# %%
# Running with p,d,q  as 1,1,1; P,D,Q,m = 1,1,1,7
# To predict last 35 values
exog.index = English_clipped.index
SARIMAX(df=English_clipped,idx=35,order=(1,1,1),seasonal_order=(1,1,1,7),exog=exog,batch=False);
# Out:
# MAE : 341.615
# RMSE : 400.202
# MAPE: 0.07

# %% [markdown]
# ### Insights:
# 1. With p,d,q and P,D,Q,m as 1,1,1 and 1,1,1,7, we got a model that predicts with an MAPE of 7%
# 2. We can do a grid search on above parameters to find the optimal p,d,q,P,D,Q values

# %%
from itertools import product
from pprint import pprint
import heapq

# %%
 def SARIMAX_mape(df,idx,order=(0,0,0),seasonal_order=(0,0,0,0),exog= None, batch=False):

    import statsmodels.api as sm

    X_train, X_test = df.iloc[:-idx],df.iloc[-idx:]

    if exog is not None:
        exog_train = exog[:-idx]
        exog_test = exog[-idx:]
    else:
        exog_train,exog_test =  None,None

    model = sm.tsa.SARIMAX(endog=X_train,
                           exog=exog_train,
                           order=order,
                           seasonal_order=seasonal_order,
                          )
    result = model.fit(disp=False)
    predTest  = result.forecast(len(X_test),dynamic=False,exog=exog_test)

    if not batch:

        predTest.plot(style="-*",label="Prediction")
        df.tail(100).plot(label="Original")
        plt.ylabel("Views")
        plt.xlabel("Date")
        plt.legend();

        performance(X_test,predTest)

    mape_val = round(mape(X_test, predTest), 3)

    return mape_val

# %%
# This grid search is for English series with exogenous variable
# Based on how it works, we can replicate it to other languages

p = d = q = range(1,3)

#Using product to create all permuatations of p,d,q,P,D,Q
pdq = list(product(p,d,q))
PDQ = [(x[0],x[1],x[2],7) for x in pdq]

all_results_mape = []

for order in pdq:
    for seasonal in PDQ:

        try:
            # MAPE is stored in the result
            result = SARIMAX_mape(df=English_clipped,
                             idx=35,order= order,seasonal_order=seasonal,exog=exog,batch=True);


            all_results_mape.append((order,seasonal,-result))
            print(order,seasonal,result)

        except:
            print(f"Skipped {order},{seasonal}")
            continue

# We store the MAPE values as negative to use nlargest function to find the best parameters
top5_results_mape = heapq.nlargest(5, all_results_mape,lambda k:k[2])
print(top5_results_mape)
# Out:
# (1, 1, 1) (1, 1, 1, 7) 0.07
# (1, 1, 1) (1, 1, 2, 7) 0.068
# (1, 1, 1) (1, 2, 1, 7) 0.046
# (1, 1, 1) (1, 2, 2, 7) 2679.368
# (1, 1, 1) (2, 1, 1, 7) 0.076
# (1, 1, 1) (2, 1, 2, 7) 0.073
# (1, 1, 1) (2, 2, 1, 7) 0.066
# Skipped (1, 1, 1),(2, 2, 2, 7)
# (1, 1, 2) (1, 1, 1, 7) 0.063
# (1, 1, 2) (1, 1, 2, 7) 0.061
# (1, 1, 2) (1, 2, 1, 7) 0.061
# (1, 1, 2) (1, 2, 2, 7) 1119.086
# (1, 1, 2) (2, 1, 1, 7) 0.069
# (1, 1, 2) (2, 1, 2, 7) 0.068
# (1, 1, 2) (2, 2, 1, 7) 0.061
# (1, 1, 2) (2, 2, 2, 7) 0.097
# (1, 2, 1) (1, 1, 1, 7) 0.063
# (1, 2, 1) (1, 1, 2, 7) 0.07
# (1, 2, 1) (1, 2, 1, 7) 0.047
# (1, 2, 1) (1, 2, 2, 7) 0.061
# (1, 2, 1) (2, 1, 1, 7) 0.07
# (1, 2, 1) (2, 1, 2, 7) 0.071
# (1, 2, 1) (2, 2, 1, 7) 0.063
# Skipped (1, 2, 1),(2, 2, 2, 7)
# (1, 2, 2) (1, 1, 1, 7) 0.07
# (1, 2, 2) (1, 1, 2, 7) 0.07
# (1, 2, 2) (1, 2, 1, 7) 0.044
# (1, 2, 2) (1, 2, 2, 7) 0.057
# (1, 2, 2) (2, 1, 1, 7) 0.056
# (1, 2, 2) (2, 1, 2, 7) 0.081
# (1, 2, 2) (2, 2, 1, 7) 0.072
# (1, 2, 2) (2, 2, 2, 7) 0.099
# (2, 1, 1) (1, 1, 1, 7) 0.064
# (2, 1, 1) (1, 1, 2, 7) 0.063
# (2, 1, 1) (1, 2, 1, 7) 0.046
# (2, 1, 1) (1, 2, 2, 7) 0.056
# (2, 1, 1) (2, 1, 1, 7) 0.071
# (2, 1, 1) (2, 1, 2, 7) 0.07
# (2, 1, 1) (2, 2, 1, 7) 0.065
# (2, 1, 1) (2, 2, 2, 7) 201520.738
# (2, 1, 2) (1, 1, 1, 7) 0.065
# (2, 1, 2) (1, 1, 2, 7) 0.077
# (2, 1, 2) (1, 2, 1, 7) 2352542.511
# Skipped (2, 1, 2),(1, 2, 2, 7)
# (2, 1, 2) (2, 1, 1, 7) 0.067
# (2, 1, 2) (2, 1, 2, 7) 0.067
# (2, 1, 2) (2, 2, 1, 7) 0.07
# Skipped (2, 1, 2),(2, 2, 2, 7)
# (2, 2, 1) (1, 1, 1, 7) 0.059
# (2, 2, 1) (1, 1, 2, 7) 0.059
# (2, 2, 1) (1, 2, 1, 7) 0.05
# (2, 2, 1) (1, 2, 2, 7) 0.056
# (2, 2, 1) (2, 1, 1, 7) 0.065
# (2, 2, 1) (2, 1, 2, 7) 0.06
# (2, 2, 1) (2, 2, 1, 7) 0.057
# (2, 2, 1) (2, 2, 2, 7) 0.063
# (2, 2, 2) (1, 1, 1, 7) 0.063
# (2, 2, 2) (1, 1, 2, 7) 0.063
# (2, 2, 2) (1, 2, 1, 7) 0.047
# (2, 2, 2) (1, 2, 2, 7) 0.061
# (2, 2, 2) (2, 1, 1, 7) 0.07
# Skipped (2, 2, 2),(2, 1, 2, 7)
# (2, 2, 2) (2, 2, 1, 7) 0.063
# (2, 2, 2) (2, 2, 2, 7) 0.069
# [((1, 2, 2), (1, 2, 1, 7), -0.044), ((1, 1, 1), (1, 2, 1, 7), -0.046), ((2, 1, 1), (1, 2, 1, 7), -0.046), ((1, 2, 1), (1, 2, 1, 7), -0.047), ((2, 2, 2), (1, 2, 1, 7), -0.047)]

# %%
# From the above grid search results- selected the best parameters
SARIMAX_mape(df=English_clipped,idx=35,order=(1,2,2),seasonal_order=(1,2,1,7),exog=exog,batch=False);
# Out:
# MAE : 224.314
# RMSE : 291.266
# MAPE: 0.044

# %% [markdown]
# ### Insights:
# 1. Using grid search, we could find optimal parameters that predicts with an MAPE of 4.4%. Better than our prior models

# %%
# Pipeline function for different languages

# 1. Dataset is available in agg_data_means[language]
# 2. Function to call Grid Search on SARIMA - EXOG is not passed
# 3. Store top 5 results for each language in Dictionary

def grid_search_sarimax(df, p, d, q, m, exog=None, idx=35):

    p,d,q = p,d,q
    pdq = list(product(p,d,q))
    PDQ = [(x[0],x[1],x[2],m) for x in pdq]

    all_results_mape = []

    for order in pdq:
        for seasonal in PDQ:

            try:
                result = SARIMAX_mape(df=df,
                                 idx=idx,order= order,seasonal_order=seasonal,exog=exog,batch=True);


                all_results_mape.append((order,seasonal,-result))
                print(f"order:{order},seasonal:{seasonal},MAPE:{result}")

            except:
                print(f"Skipped params: {order},{seasonal}")
                continue


    top5_results_mape = heapq.nlargest(5, all_results_mape,lambda k:k[2])
    return top5_results_mape

top5results_by_lang = {}

# for different languages
for language in agg_data_means.columns:

    # Dataset is available in agg_data_means[language]
    df_lang = f"df_{language}"
    df_lang = agg_data_means[language]


    # Call Grid Search
    print(f"Language:{language}")
    output = grid_search_sarimax(df_lang, p=range(1,3), d=range(1,3), q=range(1,3), m=7, exog=None, idx=35)
    top5results_by_lang[language] = output

pprint(top5results_by_lang)
# Out:
# Language:Chinese
# order:(1, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.086
# order:(1, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.086
# order:(1, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.073
# order:(1, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.07
# order:(1, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.086
# order:(1, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.086
# order:(1, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.09
# order:(1, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.05
# order:(1, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.086
# order:(1, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.086
# order:(1, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.073
# order:(1, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.037
# order:(1, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.086
# order:(1, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.086
# order:(1, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.09
# order:(1, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.05
# order:(1, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.152
# order:(1, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.153
# order:(1, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.266
# order:(1, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.351
# order:(1, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.152
# order:(1, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.148
# order:(1, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.308
# order:(1, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.172
# order:(1, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.075
# order:(1, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.071
# order:(1, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.36
# order:(1, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.469
# order:(1, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.075
# order:(1, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.07
# order:(1, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.374
# order:(1, 2, 2),seasonal:(2, 2, 2, 7),MAPE:0.206
# order:(2, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.152
# order:(2, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.152
# order:(2, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.073
# order:(2, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.037
# order:(2, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.152
# order:(2, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.154
# order:(2, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.09
# order:(2, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.032
# order:(2, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.143
# order:(2, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.085
# Skipped params: (2, 1, 2),(1, 2, 1, 7)
# order:(2, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.091
# order:(2, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.142
# order:(2, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.086
# order:(2, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.089
# Skipped params: (2, 1, 2),(2, 2, 2, 7)
# order:(2, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.129
# order:(2, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.13
# order:(2, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.206
# order:(2, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.119
# order:(2, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.129
# order:(2, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.13
# order:(2, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.264
# order:(2, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.146
# order:(2, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.071
# order:(2, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.072
# Skipped params: (2, 2, 2),(1, 2, 1, 7)
# order:(2, 2, 2),seasonal:(1, 2, 2, 7),MAPE:282712.108
# order:(2, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.072
# order:(2, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.07
# order:(2, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.265
# Skipped params: (2, 2, 2),(2, 2, 2, 7)
# Language:English
# order:(1, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.08
# order:(1, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.078
# order:(1, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.062
# order:(1, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.074
# order:(1, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.078
# order:(1, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.076
# order:(1, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.089
# order:(1, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.088
# order:(1, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.075
# order:(1, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.093
# order:(1, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.066
# order:(1, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.071
# order:(1, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.075
# order:(1, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.095
# order:(1, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.079
# order:(1, 1, 2),seasonal:(2, 2, 2, 7),MAPE:1112.534
# order:(1, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.072
# order:(1, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.072
# order:(1, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.06
# order:(1, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.072
# order:(1, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.074
# order:(1, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.089
# Skipped params: (1, 2, 1),(2, 2, 1, 7)
# order:(1, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.07
# order:(1, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.074
# order:(1, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.077
# order:(1, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.058
# order:(1, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.074
# order:(1, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.076
# order:(1, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.075
# order:(1, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.088
# order:(1, 2, 2),seasonal:(2, 2, 2, 7),MAPE:0.076
# order:(2, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.076
# order:(2, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.093
# order:(2, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.069
# Skipped params: (2, 1, 1),(1, 2, 2, 7)
# Skipped params: (2, 1, 1),(2, 1, 1, 7)
# order:(2, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.089
# order:(2, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.085
# order:(2, 1, 1),seasonal:(2, 2, 2, 7),MAPE:1.0
# Skipped params: (2, 1, 2),(1, 1, 1, 7)
# Skipped params: (2, 1, 2),(1, 1, 2, 7)
# order:(2, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.062
# order:(2, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.095
# order:(2, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.08
# Skipped params: (2, 1, 2),(2, 1, 2, 7)
# order:(2, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.086
# order:(2, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.065
# order:(2, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.068
# order:(2, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.082
# order:(2, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.065
# order:(2, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.065
# order:(2, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.07
# order:(2, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.068
# order:(2, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.073
# order:(2, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.062
# order:(2, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.072
# order:(2, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.074
# order:(2, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.06
# order:(2, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.072
# order:(2, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.074
# Skipped params: (2, 2, 2),(2, 1, 2, 7)
# order:(2, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.083
# order:(2, 2, 2),seasonal:(2, 2, 2, 7),MAPE:0.222
# Language:French
# order:(1, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.063
# order:(1, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.066
# order:(1, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.172
# order:(1, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.069
# order:(1, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.065
# order:(1, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.065
# Skipped params: (1, 1, 1),(2, 2, 1, 7)
# order:(1, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.081
# order:(1, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.063
# order:(1, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.064
# order:(1, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.182
# order:(1, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.065
# order:(1, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.065
# order:(1, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.064
# order:(1, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.095
# order:(1, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.079
# order:(1, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.064
# order:(1, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.065
# order:(1, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.179
# order:(1, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.119
# order:(1, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.064
# order:(1, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.065
# order:(1, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.101
# order:(1, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.067
# order:(1, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.069
# order:(1, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.063
# order:(1, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.065
# order:(1, 2, 2),seasonal:(1, 2, 2, 7),MAPE:1443561.622
# order:(1, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.064
# order:(1, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.063
# order:(1, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.101
# order:(1, 2, 2),seasonal:(2, 2, 2, 7),MAPE:279808408.354
# order:(2, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.066
# order:(2, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.066
# order:(2, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.089
# order:(2, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.074
# order:(2, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.067
# order:(2, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.066
# order:(2, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.078
# order:(2, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.085
# order:(2, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.064
# order:(2, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.066
# order:(2, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.155
# order:(2, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.066
# order:(2, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.065
# order:(2, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.065
# order:(2, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.077
# order:(2, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.137
# order:(2, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.063
# order:(2, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.063
# order:(2, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.174
# order:(2, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.065
# order:(2, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.063
# order:(2, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.063
# order:(2, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.094
# order:(2, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.153
# order:(2, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.064
# order:(2, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.064
# order:(2, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.193
# order:(2, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.067
# order:(2, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.064
# order:(2, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.064
# order:(2, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.101
# order:(2, 2, 2),seasonal:(2, 2, 2, 7),MAPE:0.067
# Language:German
# order:(1, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.075
# order:(1, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.075
# order:(1, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.073
# order:(1, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.074
# order:(1, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.074
# order:(1, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.075
# order:(1, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.084
# order:(1, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.067
# order:(1, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.075
# order:(1, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.075
# order:(1, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.073
# order:(1, 1, 2),seasonal:(1, 2, 2, 7),MAPE:211.962
# order:(1, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.074
# order:(1, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.075
# order:(1, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.082
# order:(1, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.069
# order:(1, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.069
# order:(1, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.069
# order:(1, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.149
# order:(1, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.075
# order:(1, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.068
# order:(1, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.069
# order:(1, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.081
# order:(1, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.072
# order:(1, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.073
# order:(1, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.073
# order:(1, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.118
# order:(1, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.081
# order:(1, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.072
# order:(1, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.071
# order:(1, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.078
# order:(1, 2, 2),seasonal:(2, 2, 2, 7),MAPE:20289788.51
# order:(2, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.075
# order:(2, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.079
# order:(2, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.073
# order:(2, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.076
# order:(2, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.074
# order:(2, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.074
# order:(2, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.082
# order:(2, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.074
# order:(2, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.074
# order:(2, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.076
# Skipped params: (2, 1, 2),(1, 2, 1, 7)
# order:(2, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.124
# order:(2, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.07
# order:(2, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.074
# order:(2, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.079
# Skipped params: (2, 1, 2),(2, 2, 2, 7)
# order:(2, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.069
# order:(2, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.071
# order:(2, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.155
# order:(2, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.075
# order:(2, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.068
# order:(2, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.069
# order:(2, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.082
# order:(2, 2, 1),seasonal:(2, 2, 2, 7),MAPE:179366.373
# order:(2, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.069
# order:(2, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.069
# order:(2, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.085
# order:(2, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.082
# order:(2, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.068
# order:(2, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.074
# order:(2, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.081
# Skipped params: (2, 2, 2),(2, 2, 2, 7)
# Language:Japanese
# order:(1, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.076
# order:(1, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.077
# order:(1, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.09
# order:(1, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.086
# order:(1, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.075
# order:(1, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.077
# order:(1, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.091
# order:(1, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.086
# order:(1, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.076
# order:(1, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.076
# order:(1, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.091
# order:(1, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.083
# order:(1, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.075
# order:(1, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.076
# order:(1, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.082
# order:(1, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.084
# order:(1, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.079
# order:(1, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.079
# order:(1, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.079
# order:(1, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.088
# order:(1, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.079
# order:(1, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.077
# order:(1, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.072
# order:(1, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.077
# order:(1, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.129
# order:(1, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.087
# order:(1, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.071
# Skipped params: (1, 2, 2),(1, 2, 2, 7)
# order:(1, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.081
# order:(1, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.086
# order:(1, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.07
# order:(1, 2, 2),seasonal:(2, 2, 2, 7),MAPE:23.712
# order:(2, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.076
# order:(2, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.076
# order:(2, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.09
# order:(2, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.092
# order:(2, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.075
# order:(2, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.077
# order:(2, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.091
# order:(2, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.086
# order:(2, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.076
# order:(2, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.076
# order:(2, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.09
# order:(2, 1, 2),seasonal:(1, 2, 2, 7),MAPE:395470.508
# order:(2, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.076
# order:(2, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.076
# order:(2, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.091
# order:(2, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.086
# order:(2, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.084
# order:(2, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.083
# order:(2, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.094
# order:(2, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.092
# order:(2, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.083
# order:(2, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.081
# order:(2, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.081
# order:(2, 2, 1),seasonal:(2, 2, 2, 7),MAPE:8521514.503
# order:(2, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.086
# order:(2, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.08
# order:(2, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.114
# order:(2, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.088
# order:(2, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.087
# order:(2, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.079
# Skipped params: (2, 2, 2),(2, 2, 1, 7)
# order:(2, 2, 2),seasonal:(2, 2, 2, 7),MAPE:0.089
# Language:Russian
# order:(1, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.124
# order:(1, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.126
# order:(1, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.104
# order:(1, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.11
# order:(1, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.123
# order:(1, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.125
# order:(1, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.079
# order:(1, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.112
# order:(1, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.143
# order:(1, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.145
# order:(1, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.129
# order:(1, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.116
# order:(1, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.144
# order:(1, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.145
# order:(1, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.153
# order:(1, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.112
# order:(1, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.114
# order:(1, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.114
# order:(1, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.148
# order:(1, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.131
# order:(1, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.115
# order:(1, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.112
# Skipped params: (1, 2, 1),(2, 2, 1, 7)
# order:(1, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.088
# order:(1, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.098
# order:(1, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.101
# order:(1, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.118
# order:(1, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.115
# order:(1, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.1
# order:(1, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.1
# order:(1, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.138
# order:(1, 2, 2),seasonal:(2, 2, 2, 7),MAPE:0.113
# order:(2, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.125
# order:(2, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.141
# order:(2, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.059
# order:(2, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.096
# order:(2, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.126
# order:(2, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.14
# order:(2, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.082
# order:(2, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.096
# order:(2, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.119
# order:(2, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.116
# order:(2, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.103
# order:(2, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.288
# order:(2, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.129
# order:(2, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.139
# Skipped params: (2, 1, 2),(2, 2, 1, 7)
# order:(2, 1, 2),seasonal:(2, 2, 2, 7),MAPE:1.0
# order:(2, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.097
# order:(2, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.093
# order:(2, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.125
# order:(2, 2, 1),seasonal:(1, 2, 2, 7),MAPE:1.311
# order:(2, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.097
# order:(2, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.091
# order:(2, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.146
# Skipped params: (2, 2, 1),(2, 2, 2, 7)
# order:(2, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.1
# order:(2, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.117
# order:(2, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.148
# order:(2, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.133
# order:(2, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.115
# order:(2, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.099
# order:(2, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.171
# Skipped params: (2, 2, 2),(2, 2, 2, 7)
# Language:Spanish
# order:(1, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.29
# order:(1, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.293
# order:(1, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.262
# order:(1, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.282
# order:(1, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.273
# order:(1, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.287
# order:(1, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.291
# order:(1, 1, 1),seasonal:(2, 2, 2, 7),MAPE:278591.866
# order:(1, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.285
# order:(1, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.294
# order:(1, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.262
# order:(1, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.255
# order:(1, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.286
# order:(1, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.287
# order:(1, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.29
# order:(1, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.343
# order:(1, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.39
# order:(1, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.394
# order:(1, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.438
# order:(1, 2, 1),seasonal:(1, 2, 2, 7),MAPE:0.69
# order:(1, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.375
# order:(1, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.378
# order:(1, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.461
# order:(1, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.434
# order:(1, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.277
# order:(1, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.273
# order:(1, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.545
# order:(1, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.485
# order:(1, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.26
# order:(1, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.298
# order:(1, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.536
# order:(1, 2, 2),seasonal:(2, 2, 2, 7),MAPE:13282287.248
# order:(2, 1, 1),seasonal:(1, 1, 1, 7),MAPE:0.284
# order:(2, 1, 1),seasonal:(1, 1, 2, 7),MAPE:0.276
# order:(2, 1, 1),seasonal:(1, 2, 1, 7),MAPE:0.263
# order:(2, 1, 1),seasonal:(1, 2, 2, 7),MAPE:0.279
# order:(2, 1, 1),seasonal:(2, 1, 1, 7),MAPE:0.286
# order:(2, 1, 1),seasonal:(2, 1, 2, 7),MAPE:0.287
# order:(2, 1, 1),seasonal:(2, 2, 1, 7),MAPE:0.289
# order:(2, 1, 1),seasonal:(2, 2, 2, 7),MAPE:0.31
# order:(2, 1, 2),seasonal:(1, 1, 1, 7),MAPE:0.325
# order:(2, 1, 2),seasonal:(1, 1, 2, 7),MAPE:0.318
# order:(2, 1, 2),seasonal:(1, 2, 1, 7),MAPE:0.519
# order:(2, 1, 2),seasonal:(1, 2, 2, 7),MAPE:0.415
# order:(2, 1, 2),seasonal:(2, 1, 1, 7),MAPE:0.303
# order:(2, 1, 2),seasonal:(2, 1, 2, 7),MAPE:0.361
# order:(2, 1, 2),seasonal:(2, 2, 1, 7),MAPE:0.519
# order:(2, 1, 2),seasonal:(2, 2, 2, 7),MAPE:0.39
# order:(2, 2, 1),seasonal:(1, 1, 1, 7),MAPE:0.352
# order:(2, 2, 1),seasonal:(1, 1, 2, 7),MAPE:0.35
# order:(2, 2, 1),seasonal:(1, 2, 1, 7),MAPE:0.35
# Skipped params: (2, 2, 1),(1, 2, 2, 7)
# order:(2, 2, 1),seasonal:(2, 1, 1, 7),MAPE:0.331
# order:(2, 2, 1),seasonal:(2, 1, 2, 7),MAPE:0.349
# order:(2, 2, 1),seasonal:(2, 2, 1, 7),MAPE:0.382
# order:(2, 2, 1),seasonal:(2, 2, 2, 7),MAPE:0.339
# order:(2, 2, 2),seasonal:(1, 1, 1, 7),MAPE:0.272
# order:(2, 2, 2),seasonal:(1, 1, 2, 7),MAPE:0.269
# order:(2, 2, 2),seasonal:(1, 2, 1, 7),MAPE:0.431
# order:(2, 2, 2),seasonal:(1, 2, 2, 7),MAPE:0.462
# order:(2, 2, 2),seasonal:(2, 1, 1, 7),MAPE:0.254
# order:(2, 2, 2),seasonal:(2, 1, 2, 7),MAPE:0.27
# order:(2, 2, 2),seasonal:(2, 2, 1, 7),MAPE:0.458
# order:(2, 2, 2),seasonal:(2, 2, 2, 7),MAPE:0.418
# {'Chinese': [((2, 1, 1), (2, 2, 2, 7), -0.032),
#              ((1, 1, 2), (1, 2, 2, 7), -0.037),
#              ((2, 1, 1), (1, 2, 2, 7), -0.037),
#              ((1, 1, 1), (2, 2, 2, 7), -0.05),
#              ((1, 1, 2), (2, 2, 2, 7), -0.05)],
#  'English': [((1, 2, 2), (1, 2, 1, 7), -0.058),
#              ((1, 2, 1), (1, 2, 1, 7), -0.06),
#              ((2, 2, 2), (1, 2, 1, 7), -0.06),
#              ((1, 1, 1), (1, 2, 1, 7), -0.062),
#              ((2, 1, 2), (1, 2, 1, 7), -0.062)],
#  'French': [((1, 1, 1), (1, 1, 1, 7), -0.063),
#             ((1, 1, 2), (1, 1, 1, 7), -0.063),
#             ((1, 2, 2), (1, 1, 2, 7), -0.063),
#             ((1, 2, 2), (2, 1, 2, 7), -0.063),
#             ((2, 2, 1), (1, 1, 1, 7), -0.063)],
#  'German': [((1, 1, 1), (2, 2, 2, 7), -0.067),
#             ((1, 2, 1), (2, 1, 1, 7), -0.068),
#             ((2, 2, 1), (2, 1, 1, 7), -0.068),
#             ((2, 2, 2), (2, 1, 1, 7), -0.068),
#             ((1, 1, 2), (2, 2, 2, 7), -0.069)],
#  'Japanese': [((1, 2, 2), (2, 2, 1, 7), -0.07),
#               ((1, 2, 2), (1, 2, 1, 7), -0.071),
#               ((1, 2, 1), (2, 2, 1, 7), -0.072),
#               ((1, 1, 1), (2, 1, 1, 7), -0.075),
#               ((1, 1, 2), (2, 1, 1, 7), -0.075)],
#  'Russian': [((2, 1, 1), (1, 2, 1, 7), -0.059),
#              ((1, 1, 1), (2, 2, 1, 7), -0.079),
#              ((2, 1, 1), (2, 2, 1, 7), -0.082),
#              ((1, 2, 1), (2, 2, 2, 7), -0.088),
#              ((2, 2, 1), (2, 1, 2, 7), -0.091)],
#  'Spanish': [((2, 2, 2), (2, 1, 1, 7), -0.254),
#              ((1, 1, 2), (1, 2, 2, 7), -0.255),
#              ((1, 2, 2), (2, 1, 1, 7), -0.26),
#              ((1, 1, 1), (1, 2, 1, 7), -0.262),
#              ((1, 1, 2), (1, 2, 1, 7), -0.262)]}

# %% [markdown]
# ### Chinese:

# %%
order, seasonal = (2,1,1),(2,2,2,7)
SARIMAX_mape(df=agg_data_means["Chinese"],idx=35,order= order,seasonal_order=seasonal,exog=None,batch=False);
# Out:
# MAE : 11.907
# RMSE : 14.773
# MAPE: 0.032

# %% [markdown]
# ## English:

# %%
order, seasonal = (1,2,2),(1,2,1,7)
SARIMAX_mape(df=agg_data_means["English"],idx=35,order= order,seasonal_order=seasonal,exog=None,batch=False);
# Out:
# MAE : 305.381
# RMSE : 452.437
# MAPE: 0.058

# %% [markdown]
# ## German:

# %%
order, seasonal = (1,1,1),(2,2,2,7)
SARIMAX_mape(df=agg_data_means["German"],idx=35,order= order,seasonal_order=seasonal,exog=None,batch=False);
# Out:
# MAE : 70.072
# RMSE : 115.944
# MAPE: 0.067

# %% [markdown]
# ## Japanese:

# %%
order, seasonal = (1,2,2),(2,2,1,7)
SARIMAX_mape(df=agg_data_means["Japanese"],idx=35,order= order,seasonal_order=seasonal,exog=None,batch=False);
# Out:
# MAE : 58.563
# RMSE : 85.44
# MAPE: 0.07

# %% [markdown]
# ## Russian:

# %%
order, seasonal = (2,1,1),(1,2,1,7)
SARIMAX_mape(df=agg_data_means["Russian"],idx=35,order= order,seasonal_order=seasonal,exog=None,batch=False);
# Out:
# MAE : 56.968
# RMSE : 69.212
# MAPE: 0.059

# %% [markdown]
# ## Spanish

# %%
# For spanish, predicting last month worked better compared to predicting last 35 days
order, seasonal = (1,1,0),(1,0,1,7)
SARIMAX_mape(df=agg_data_means["Spanish"],idx=30,order= order,seasonal_order=seasonal,exog=None,batch=False);
# Out:
# MAE : 92.815
# RMSE : 112.812
# MAPE: 0.088

# %% [markdown]
# ### Insights:
# 1. As shown above, average pages views for each language are predicted using the best parameters from Grid Search on SARIMAX without exogenous variable
# 2. MAPE of English increased by ~2% without inclusion of campaign data during training
# 3. For Spanish, we did well in prediction of last 30 days than last 35 days

# %% [markdown]
# ## Prophet

# %%
from prophet import Prophet
from prophet.plot import add_changepoints_to_plot

# %%
# prepare the data for using prophet
prophet_input = English_clipped.reset_index().rename(columns={"index":"ds","English":"y"})
train_data,test_data = prophet_input.iloc[:-35],prophet_input.iloc[-35:]

# %%
# Trying to predict with 95% confidence intervals
fbmodel = Prophet(weekly_seasonality=True,interval_width=0.95)
fbmodel.fit(train_data)
# Out:
# 17:23:11 - cmdstanpy - INFO - Chain [1] start processing
# 17:23:12 - cmdstanpy - INFO - Chain [1] done processing

# %%
# This is to create timeseries dataframe automatically
forecast_period = fbmodel.make_future_dataframe(periods=35,freq="D",include_history=True)

# %%
# Store the forecast
prophet_forecast = fbmodel.predict(forecast_period)

# %%
# Plot the changepoints, forecast along with confidence interval
fig = fbmodel.plot(prophet_forecast,uncertainty=True)
a = add_changepoints_to_plot(fig.gca(),fbmodel,prophet_forecast)

# %%
# As expected, prophet could find trend and weekly seasonality
fbmodel.plot_components(prophet_forecast);

# %%
# Check how prophet did
performance(test_data["y"].values,prophet_forecast["yhat"][-35:].values)
# Out:
# MAE : 315.392
# RMSE : 459.583
# MAPE: 0.059

# %% [markdown]
# ### Insights:
# 1. Without exogenous variables and not much tweaking, it was able to find a model that predicts average daily pages views with MAPE of ~5.9%

# %% [markdown]
# ## Prophet with campaign data

# %%
# prepare the data for using prophet
prophet_input = English_clipped.reset_index().rename(columns={"index":"ds","English":"y"})
prophet_input = prophet_input.merge(exog.reset_index(drop=True),left_index=True,right_index=True)
train_data,test_data = prophet_input.iloc[:-35],prophet_input.iloc[-35:]

# %%
# Trying to predict with 95% confidence intervals
fbmodel2 = Prophet(weekly_seasonality=True,interval_width=0.95)
fbmodel2.add_regressor("Exog")
fbmodel2.fit(train_data)
# Out:
# 17:23:39 - cmdstanpy - INFO - Chain [1] start processing
# 17:23:40 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Store the forecast
prophet_forecast2 = fbmodel2.predict(prophet_input)

# %%
# Plot the changepoints, forecast along with confidence interval
fig = fbmodel2.plot(prophet_forecast2,uncertainty=True)
a = add_changepoints_to_plot(fig.gca(),fbmodel2,prophet_forecast2)

# %%
fbmodel2.plot_components(prophet_forecast2);

# %%
performance(test_data["y"].values,prophet_forecast2["yhat"][-35:].values)
# Out:
# MAE : 279.542
# RMSE : 402.26
# MAPE: 0.053

# %% [markdown]
# ### Insights:
# 1. Prophet with campain data is able to predict better. MAPE of ~5%

# %% [markdown]
# ## Inferences :

# %% [markdown]
# 1. There are also mediawiki & commons.wikimedia pages that host media are available in the dataset
# 2. Of the pages from 7 different languages, English has the highest proportion, closely followed by Japanese. Rest of the languages roughly have same proportion of ~12%
# 3. AccessOrigin is spider for ~24% of the pages and all-agents for ~76%
# 4. AccessType is all-acess for about 50% of the pages. Then for desktop & mobile-web is ~25% each
# 6. During the months of August 2016, there is a spike in daily average views of both English & Russian pages
# 7. Also, a spike is observed in Nov,2016. This time for pages in Spanish, Russian, and German as well
# 8. English average views seem to have trend & seasonality where as other languages have seasonality mostly
# 9. In daily median views, Spanish language pages seem to be higher than other language pages
# 10. Spanish, Russian, and English median daily views had a drop.
# 11. In later months of 2016, english pages median daily views is on part with that of Spanish

# %% [markdown]
# ## Recommendations:
# 1. English has high average daily views compared to other languages. Recommend running more ads in English pages
# 2. There are more than 50% of pages with all-access compared to desktop & mobile-web alone
# 3. Knowing the language for mediawiki & commons.wikimedia would enhance our training data further
# 4. Like campaign data for English pages, availability of such exogenous data would improve model predictions
# 5. With more time and resources, we can experiment with prophet parameters to bring better MAPE values.
